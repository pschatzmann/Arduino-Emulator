// %% [markdown]
// # TinyFTPClient
//
// I have changed my FTPClient to a header only library. So let's check if we can use it in the Emulator?

// %%
#pragma cling add_include_path("ArduinoCore-API/api")
#pragma cling add_include_path("ArduinoCore-Linux/cores/arduino")
#pragma cling add_include_path("ArduinoCore-Linux/libraries/Tiny")
#pragma cling add_library_path("build") 
#pragma cling load("libarduino_emulator")

// %%
#include "Arduino.h"
#include "WiFi.h"

#include "Arduino.h"
#include "WiFi.h"

void setupWifi() {
    Serial.begin(115200);
    Logger.setLogger(Serial, Logger.Warning);
    delay(10);

    Serial.println();
    Serial.println();
    Serial.print("Connecting to Network...");

    WiFi.begin("ssid not relevant", "password not relevant");
    while (WiFi.status() != WL_CONNECTED) {
        delay(500);
        Serial.print(".");
    }

    Serial.println();
    Serial.println("WiFi connected");
    Serial.print("IP address: ");
    Serial.println(WiFi.localIP());
}

setupWifi();
// Out:
// Connecting to Network...
// WiFi connected
// IP address: 172.22.0.2

// %%
#include "TinyFTPClient.h"

void setup() {
    Serial.begin(115200);

    // connect to WIFI
    WiFi.begin("network name", "password");
    while (WiFi.status() != WL_CONNECTED) {
      delay(500);
      Serial.print(".");
    }

    IPAddress localAddress = WiFi.localIP();
    Serial.println();
    Serial.print("Started with address ");
    Serial.println(localAddress.toString());

    // optional logging
    FTPLogger::setOutput(Serial);
    //FTPLogger::setLogLevel(LOG_DEBUG);

    // open connection
    client.begin(IPAddress(192,168,1,10), "user", "password");

    FTPFileIterator it = client.ls("/");
    for (auto fileIt = it.begin(); fileIt != it.end(); fileIt++)  {
        FTPFile file = *fileIt;
        Serial.println(file.name());
    }
    
    // clenaup
    client.end();
}

setup();
// Out:
// In file included from input_line_10:1:
// ArduinoCore-Linux/libraries/Tiny/TinyFTPClient.h:166:29: error: reference to 'LogLevel' is ambiguous
//     static void setLogLevel(LogLevel level){
//                             ^
// ArduinoCore-Linux/libraries/Tiny/TinyFTPClient.h:44:6: note: candidate found by name lookup is 'LogLevel'
// enum LogLevel  { LOG_DEBUG, LOG_INFO, LOG_WARN, LOG_ERROR };
//      ^
// ArduinoCore-Linux/cores/arduino/ArduinoLogger.h:11:6: note: candidate found by name lookup is 'arduino::LogLevel'
// enum LogLevel {
//      ^
// In file included from input_line_10:1:
// ArduinoCore-Linux/libraries/Tiny/TinyFTPClient.h:170:12: error: reference to 'LogLevel' is ambiguous
//     static LogLevel getLogLevel(){
//            ^
// ArduinoCore-Linux/libraries/Tiny/TinyFTPClient.h:44:6: note: candidate found by name lookup is 'LogLevel'
// enum LogLevel  { LOG_DEBUG, LOG_INFO, LOG_WARN, LOG_ERROR };
//      ^
// ...
